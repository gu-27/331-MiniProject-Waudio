# %% [markdown]
# <a href="https://colab.research.google.com/github/gu-27/331-MiniProject-Waudio/blob/Dev/MiniProjectShare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is my mini project

# %%
print ("hellos")
# Out:
# hello

# %%
# prompt: i have a csv file in the main documents folder called SampleScores.csv, import this into my program using pandas dataframes

import pandas as pd



# Read the CSV file from your Google Drive
df = pd.read_csv('NBA+games.csv')

# Print the DataFrame to see its contents
df
# Out:
# <ipython-input-8-0ed49203737d>:8: DtypeWarning: Columns (68,69,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('NBA+games.csv')
#              game_id game_date  OT H_A Team_Abbrev  Team_Score  Team_pace  \
# 0       202204100BRK   4/10/22   0   A         IND         126      103.9
# 1       202204100BRK   4/10/22   0   A         IND         126      103.9
# 2       202204100BRK   4/10/22   0   A         IND         126      103.9
# 3       202204100BRK   4/10/22   0   A         IND         126      103.9
# 4       202204100BRK   4/10/22   0   A         IND         126      103.9
# ...              ...       ...  ..  ..         ...         ...        ...
# 121102  202003070GSW    3/7/20   0   H         GSW         118       90.9
# 121103  202003070GSW    3/7/20   0   H         GSW         118       90.9
# 121104  202003070GSW    3/7/20   0   H         GSW         118       90.9
# ...

# %%
# prompt: create a new dataframe called IND_df where only Team_Abbrev is IND

IND_df = df[df['Team_Abbrev'] == 'IND']

IND_df
# Out:
#             game_id game_date  OT H_A Team_Abbrev  Team_Score  Team_pace  \
# 0      202204100BRK   4/10/22   0   A         IND         126      103.9
# 1      202204100BRK   4/10/22   0   A         IND         126      103.9
# 2      202204100BRK   4/10/22   0   A         IND         126      103.9
# 3      202204100BRK   4/10/22   0   A         IND         126      103.9
# 4      202204100BRK   4/10/22   0   A         IND         126      103.9
# ...             ...       ...  ..  ..         ...         ...        ...
# 90115  202001260POR   1/26/20   0   A         IND         129      100.2
# 90116  202001260POR   1/26/20   0   A         IND         129      100.2
# 90117  202001260POR   1/26/20   0   A         IND         129      100.2
# 90118  202001260POR   1/26/20   0   A         IND         129      100.2
# 90119  202001260POR   1/26/20   0   A         IND         129      100.2
#
#        Team_efg_pct  Team_tov_pct  Team_orb_pct  ...  pf_per_minute     ts  \
# ...
